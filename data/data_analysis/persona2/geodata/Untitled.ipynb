# %%
### 한글 폰트 설치
# !apt-get install -y fonts-nanum
# !fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# 설치 후 colab의 경우 Runtime > Restart session 필요
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# Font directories:
# 	/root/.local/share/fonts
# 	/usr/local/share/fonts
# 	/usr/share/fonts
# 	/root/.fonts
# 	/usr/share/fonts/truetype
# 	/usr/share/fonts/truetype/dejavu
# 	/usr/share/fonts/truetype/liberation
# 	/usr/share/fonts/truetype/nanum
# /root/.local/share/fonts: skipping, no such directory
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/dejavu: caching, new cache contents: 22 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc('font', family='NanumBarunGothic') # 혹은 다른 설치한 Nanum 폰트 사용

# %%
import pandas as pd
import seaborn as sns

# %%
KOREA = gpd.read_file('../geodata/ctprvn.shp', encoding='EUC-KR')
KOREA
# Out:
#    CTPRVN_CD         CTP_ENG_NM CTP_KOR_NM  \
# 0         11              Seoul      서울특별시
# 1         26              Busan      부산광역시
# 2         27              Daegu      대구광역시
# 3         28            Incheon      인천광역시
# 4         29            Gwangju      광주광역시
# 5         30            Daejeon      대전광역시
# 6         31              Ulsan      울산광역시
# 7         36          Sejong-si    세종특별자치시
# 8         41        Gyeonggi-do        경기도
# 9         43  Chungcheongbuk-do       충청북도
# 10        44  Chungcheongnam-do       충청남도
# 11        45       Jeollabuk-do       전라북도
# 12        46        Jellanam-do       전라남도
# 13        47   Gyeongsangbuk-do       경상북도
# 14        48   Gyeongsangnam-do       경상남도
# 15        50            Jeju-do    제주특별자치도
# 16        51         Gangwon-do    강원특별자치도
#
#                                              geometry
# 0   POLYGON ((966987.226 1941110.946, 966987.119 1...
# 1   MULTIPOLYGON (((1148194.981 1685460.055, 11481...
# ...

# %%
import pandas as pd

data = {
    'card_season': ['봄', '여름', '가을', '겨울', '봄', '여름', '가을', '겨울', '봄', '여름', '가을', '겨울', '봄', '여름', '가을', '겨울', '봄', '여름', '가을', '겨울', '봄', '여름', '가을', '겨울', '봄', '여름', '가을', '겨울', '봄', '여름', '가을', '겨울', '봄', '여름', '가을', '겨울', '봄', '여름', '가을', '겨울', '봄', '여름', '가을', '겨울', '봄', '여름', '가을', '겨울', '봄', '여름', '가을', '겨울', '봄', '여름', '가을', '겨울'],
    'region': ['강원', '강원', '강원', '강원', '경기', '경기', '경기', '경기', '경남', '경남', '경남', '경남', '경북', '경북', '경북', '경북', '광주', '광주', '광주', '대구', '대구', '대구', '대구', '대전', '대전', '대전', '대전', '부산', '부산', '부산', '부산', '서울', '서울', '서울', '서울', '세종', '세종', '세종', '세종', '울산', '울산', '울산', '울산', '인천', '인천', '인천', '인천', '전남', '전남', '전남', '전남', '전북', '전북', '전북', '전북', '제주', '제주', '제주', '제주', '충남', '충남', '충남', '충남', '충북', '충북', '충북', '충북'],
    'value': [0.542963, 0.545039, 0.537969, 0.574776, 0.532195, 0.52377, 0.559245, 0.537317, 0.566447, 0.565811, 0.575538, 0.578621, 0.551642, 0.543692, 0.565303, 0.531351, 0.475, 0.546667, 0.43, None, 0.57, 0.528667, 0.505714, 0.5125, None, 0.507143, 0.496364, None, 0.560625, 0.569796, 0.5625, 0.605385, 0.522947, 0.557978, 0.550288, 0.5425, 0.57, 0.44, 0.67, 0.48, 0.533333, 0.56, 0.573636, 0.55375, 0.5225, 0.538, 0.522143, 0.524167, 0.588889, 0.583448, 0.585172, 0.616667, 0.550526, 0.573667, 0.591379, 0.624737, 0.576224, 0.589439, 0.580706, 0.582771, 0.551795, 0.558462, 0.567931,
# Out:
#   Cell In[9], line 6
#     'value': [0.542963, 0.545039, 0.537969, 0.574776, 0.532195, 0.52377, 0.559245, 0.537317, 0.566447, 0.565811, 0.575538, 0.578621, 0.551642, 0.543692, 0.565303, 0.531351, 0.475, 0.546667, 0.43, None, 0.57, 0.528667, 0.505714, 0.5125, None, 0.507143, 0.496364, None, 0.560625, 0.569796, 0.5625, 0.605385, 0.522947, 0.557978, 0.550288, 0.5425, 0.57, 0.44, 0.67, 0.48, 0.533333, 0.56, 0.573636, 0.55375, 0.5225, 0.538, 0.522143, 0.524167, 0.588889, 0.583448, 0.585172, 0.616667, 0.550526, 0.573667, 0.591379, 0.624737, 0.576224, 0.589439, 0.580706, 0.582771, 0.551795, 0.558462, 0.567931,
# ...

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt
# 파이차트 그리기
KOREA.plot(column='봄', cmap='OrRd', figsize=(15, 10), legend=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.11/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '봄'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[8], line 5
#       3 import matplotlib.pyplot as plt
#       4 # 파이차트 그리기
# ...
