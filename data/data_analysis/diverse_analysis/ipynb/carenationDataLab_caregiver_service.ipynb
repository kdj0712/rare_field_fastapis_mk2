# %% [markdown]
# # 기본세팅

# %%
### 한글 폰트 설치
# !apt-get install -y fonts-nanum
# !fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# 설치 후 colab의 경우 Runtime > Restart session 필요
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fonts-nanum is already the newest version (20200506-1).
# 0 upgraded, 0 newly installed, 0 to remove and 0 not upgraded.
# Font directories:
# 	/root/.local/share/fonts
# 	/usr/local/share/fonts
# 	/usr/share/fonts
# 	/root/.fonts
# 	/usr/share/fonts/truetype
# 	/usr/share/fonts/truetype/dejavu
# 	/usr/share/fonts/truetype/liberation
# 	/usr/share/fonts/truetype/nanum
# /root/.local/share/fonts: skipping, no such directory
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/dejavu: caching, new cache contents: 22 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 12 fonts, 0 dirs
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
mpl.rc('font', family='NanumBarunGothic') # 혹은 다른 설치한 Nanum 폰트 사용

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import scipy
import scipy.stats as stats

# %%
import pandas as pd

data = {
    '질환': ['간경화/간경변', '간암', '갑상선암', '고관절', '골절', '난소암', '노환', '뇌경색', '뇌암/뇌종양', '뇌졸중', '뇌출혈', '담낭염', '담도암/담낭암/담관암', '대장암/결장암/직장암', '루게릭', '방광암', '식도암', '신우염', '신장암', '심장', '위암', '유방암', '인공관절', '자궁근종', '자궁암', '자궁적출', '전립선비대증', '전립선암', '지주막하출혈', '척추골절', '척추협착증', '췌장암', '치매', '파킨슨', '폐렴', '폐암', '피부암', '하체골절', '항암치료', '허리디스크', '혈액암', '기타 암'],
    '질환별 평균 지원금액(단위: 원) - 당월(2024년 3월)': [143334, 136186, 126629, 138933, 126621, 133568, 138888, 138000, 141635, 139886, 140989, 129400, 140178, 134211, 147184, 122666, 142670, 140043, 134810, 123316, 134698, 130773, 131632, 135118, 138830, 123187, 141318, 133351, 159128, 137278, 127500, 130370, 145661, 144738, 139457, 141580, 130000, 125412, 139863, 137330, 141350, 137800],
    '질환별 평균 지원금액(단위: 원) - 전체(2020년 9월~2024년 3월)': [142730, 135676, 124985, 136950, 129075, 134414, 139876, 140701, 139945, 140266, 145023, 133841, 135257, 136062, 145931, 134343, 138783, 139371, 133346, 135214, 133579, 130205, 126393, 129539, 138909, 122054, 134416, 135333, 144944, 135386, 132434, 132825, 139269, 142281, 144990, 135525, 134699, 128358, 131239, 126580, 138877, 136721],
    '질환별 공고의 평균 돌봄 기간(단위: 일) - 당월(2024년 3월)': [3.8, 7.3, 7, 8.5, 7.9, 5.6, 11.8, 15.4, 8.7, 15.5, 16.3, 2.5, 6.5, 8.9, 12.3, 4.1, 6.4, 4.8, 2.5, 4.8, 7.7, 4.7, 12.6, 2.7, 4.7, 3.2, 3, 8.4, 8.3, 7.8, 7, 6.6, 15.5, 9.7, 7.6, 13.3, 10.8, 8.7, 11.6, 3.7, 7.4, 7.4],
    '질환별 공고의 평균 돌봄 기간(단위: 일) - 전체(2020년 9월~2024년 3월)': [7.5, 8.6, 4.3, 11.7, 10.1, 7.3, 17.7, 13, 10.8, 11.4, 18.5, 6.3, 7.5, 6.4, 20.4, 6.7, 7.6, 5.2, 5.7, 9.1, 7.5, 5.7, 8.3, 2.3, 6.2, 2.6, 6.1, 8.5, 14.3, 12.8, 7.5, 8.3, 7.6, 14.5, 7.3, 8.9, 5.7, 8.3, 7.7, 6, 8.7, 8.8]
}

df_disease_amount = pd.DataFrame(data)
df_disease_amount
# Out:
#              질환  질환별 평균 지원금액(단위: 원) - 당월(2024년 3월)  \
# 0       간경화/간경변                             143334
# 1            간암                             136186
# 2          갑상선암                             126629
# 3           고관절                             138933
# 4            골절                             126621
# 5           난소암                             133568
# 6            노환                             138888
# 7           뇌경색                             138000
# 8        뇌암/뇌종양                             141635
# 9           뇌졸중                             139886
# 10          뇌출혈                             140989
# 11          담낭염                             129400
# 12  담도암/담낭암/담관암                             140178
# 13  대장암/결장암/직장암                             134211
# 14          루게릭                             147184
# 15          방광암                             122666
# 16          식도암                             142670
# ...

# %% [markdown]
# ## 케어메이트 선호지역 분포

# %%
region = {
    '지역명': ['서울', '부산', '인천', '대구', '광주', '대전', '울산', '경기', '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주', '세종'],
    '당월(2024년 3월)(%)': [2.2, 6, 6, 3.8, 14.2, 5.7, 1.5, 19.2, 6.2, 5.3, 6.5, 6.3, 5.9, 2.6, 6.6, 1.1, 1],
    '전체(2020년 9월 ~ 2024년 3월)(%)': [21.9, 5.4, 5.5, 4.8, 6.9, 4.6, 1.5, 17.8, 3.6, 3.1, 4.4, 4.7, 4.6, 2.8, 6.3, 1.5, 0.6]
}

df_caremate_region = pd.DataFrame(region)
df_caremate_region
# Out:
#    지역명  당월(2024년 3월)(%)  전체(2020년 9월 ~ 2024년 3월)(%)
# 0   서울              2.2                        21.9
# 1   부산              6.0                         5.4
# 2   인천              6.0                         5.5
# 3   대구              3.8                         4.8
# 4   광주             14.2                         6.9
# 5   대전              5.7                         4.6
# 6   울산              1.5                         1.5
# 7   경기             19.2                        17.8
# 8   강원              6.2                         3.6
# 9   충북              5.3                         3.1
# 10  충남              6.5                         4.4
# 11  전북              6.3                         4.7
# 12  전남              5.9                         4.6
# 13  경북              2.6                         2.8
# 14  경남              6.6                         6.3
# 15  제주              1.1                         1.5
# 16  세종              1.0                         0.6

# %%
# 막대의 위치
bar_width = 0.35
index = np.arange(len(df_caremate_region['지역명']))

plt.figure(figsize=(12, 8))

plt.bar(index, df_caremate_region['당월(2024년 3월)(%)'], bar_width, alpha=0.7, label='당월(2024년 3월)(%)')
plt.bar(index + bar_width, df_caremate_region['전체(2020년 9월 ~ 2024년 3월)(%)'], bar_width, alpha=0.7, label='전체(2020년 9월 ~ 2024년 3월)(%)')

plt.title('케어메이트 선호 지역 분포')
plt.xlabel('지역명')
plt.ylabel('선호도')
plt.xticks(index + bar_width / 2, df_caremate_region['지역명'])
plt.legend()

plt.show()

# %%
plt.figure(figsize=(12, 8))

plt.plot(df_patient_region['지역명'], df_patient_region['당월(2024년 3월)(%)'], marker='o', label='당월(2024년 3월)(%)')
plt.plot(df_patient_region['지역명'], df_patient_region['전체(2020년 9월 ~ 2024년 3월)(%)'], marker='o', label='전체(2020년 9월 ~ 2024년 3월)(%)')

plt.title('케어메이트 선호 지역 분포')
plt.xlabel('지역명')
plt.ylabel('케어메이트 선호도')
plt.xticks(rotation=45)
plt.legend()

plt.show()

# %% [markdown]
# ## 환자 지역별 분포

# %%
patient = {
    '지역명': ['서울', '부산', '인천', '대구', '광주', '대전', '울산', '경기', '강원', '충북', '충남', '전북', '전남', '경북', '경남', '제주', '세종'],
    '당월(2024년 3월)(%)': [21, 4.6, 3.9, 3.4, 10.5, 4.6, 0.9, 15.7, 4, 3.2, 3, 5.9, 6.6, 2.4, 7.3, 1.9, 1],
    '전체(2020년 9월 ~ 2024년 3월)(%)': [36.6, 4.1, 3.9, 3, 5.2, 4.4, 0.8, 19.8, 3, 2.3, 3.5, 3.4, 3.1, 1.9, 3.8, 0.7, 0.5]
}

df_patient_region = pd.DataFrame(patient)
df_patient_region
# Out:
#    지역명  당월(2024년 3월)(%)  전체(2020년 9월 ~ 2024년 3월)(%)
# 0   서울             21.0                        36.6
# 1   부산              4.6                         4.1
# 2   인천              3.9                         3.9
# 3   대구              3.4                         3.0
# 4   광주             10.5                         5.2
# 5   대전              4.6                         4.4
# 6   울산              0.9                         0.8
# 7   경기             15.7                        19.8
# 8   강원              4.0                         3.0
# 9   충북              3.2                         2.3
# 10  충남              3.0                         3.5
# 11  전북              5.9                         3.4
# 12  전남              6.6                         3.1
# 13  경북              2.4                         1.9
# 14  경남              7.3                         3.8
# 15  제주              1.9                         0.7
# 16  세종              1.0                         0.5

# %%
# 막대의 위치
bar_width = 0.35
index = np.arange(len(df_patient_region['지역명']))

plt.figure(figsize=(12, 8))

plt.bar(index, df_patient_region['당월(2024년 3월)(%)'], bar_width, alpha=0.7, label='당월(2024년 3월)(%)')
plt.bar(index + bar_width, df_patient_region['전체(2020년 9월 ~ 2024년 3월)(%)'], bar_width, alpha=0.7, label='전체(2020년 9월 ~ 2024년 3월)(%)')

plt.title('지역별 환자 분포')
plt.xlabel('지역명')
plt.ylabel('환자 거주율')
plt.xticks(index + bar_width / 2, df_patient_region['지역명'])
plt.legend()

plt.show()

# %%
plt.figure(figsize=(12, 8))

plt.plot(df_patient_region['지역명'], df_patient_region['당월(2024년 3월)(%)'], marker='o', label='당월(2024년 3월)(%)')
plt.plot(df_patient_region['지역명'], df_patient_region['전체(2020년 9월 ~ 2024년 3월)(%)'], marker='o', label='전체(2020년 9월 ~ 2024년 3월)(%)')

plt.title('지역별 환자 분포')
plt.xlabel('지역명')
plt.ylabel('환자 거주율')
plt.legend()
plt.xticks(rotation=45)

plt.show()

# %% [markdown]
# ## 결론
# 1) 케어메이트의 선호지역 : 2024년 3월 기준은 타 지역에 비해 떨어지나, 전체기간으로 봤을때는 가장 높음.
# 2) 환자 거주지역 : 2024년 3월 기준 및 전체기간 모두 '서울'이 가장 높음.
#
#       ▶ 케어메이트의 선호지역, 환자 거주지역 모두 '서울'로 일치하므로 '서울'에서의 서비스에 집중
